# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
cc=pd.read_csv("C:/Users/pal/Desktop/projects/project_4/creditcard.csv")

# %%
cc.head(2)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
#
# [2 rows x 31 columns]

# %%
cc.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
cc.isnull().any()
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Class     False
# dtype: bool

# %%
count = cc['Class'].value_counts()
print("Total count in each class\n\n",count)
# Out:
# Total count in each class
#
#  0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# So there are 492 frauds out of 284,807 transactions shows that this data is very imbalanced. to solve this problem we should create a sub sample of the dataframe in order to have an equal amount of Fraud and Non-Fraud cases, helping our algorithms better understand patterns that determines whether a transaction is a fraud or not.

# %%
cc.hist(figsize=(20,20))
plt.show()

# %% [markdown]
# Odserved that,all the variable are not at the same scale and distribution. Some of the variables have a wide range of values. Machine learning algorithms can’t estimate correct output without the standard normally distributed data. StandardScaler function will use from scikit-learn to standardize our data.

# %% [markdown]
# # Pre processing

# %% [markdown]
# Feature "Time" does not indicate the actual time of the transaction. So we assume that the "Time" feature has little or no significance in classifying a fraud transaction. Therefore, time column has been eliminate for further analysis.

# %%
cc= cc.drop(['Time'],axis=1)

# %%
cc = cc.sample(frac=1)

fraud_cc = cc.loc[cc['Class'] == 1]
non_fraud_cc = cc.loc[cc['Class'] == 0][:492]

normal_distributed_cc = pd.concat([fraud_cc, non_fraud_cc])

# Shuffle dataframe rows
new_cc = normal_distributed_cc.sample(frac=1, random_state=42)
new_cc.head()
# Out:
#               V1        V2         V3        V4        V5        V6        V7  \
# 13549  -0.332359  1.107197   1.085649 -0.042669  0.552809 -0.150116  0.431033
# 91671  -0.639191 -0.085595   1.265452  1.401166 -0.260542  1.009795  1.301999
# 116381  1.088291 -0.003917  -0.170787  0.343995  0.128039 -0.253261  0.307865
# 208651  0.630579  1.183631  -5.066283  2.179903 -0.703376 -0.103614 -3.490350
# 8615   -3.891192  7.098916 -11.426467  8.607557 -2.065706 -2.985288 -8.138589
#
#               V8        V9        V10  ...       V21       V22       V23  \
# 13549   0.087734  0.789076  -0.689108  ... -0.426362 -0.975942 -0.116014
# 91671  -0.135258 -0.431521  -0.091353  ...  0.340331  0.760170  0.353377
# 116381 -0.018992 -0.396708   0.045764  ... -0.287786 -1.032985  0.066752
# 208651  1.094734 -0.717418  -5.179935  ...  0.621622  0.043807  0.102711
# 8615    2.973928 -6.272790 -13.193415  ...  1.757085 -0.189709 -0.508629
#
# ...

# %%
new_cc.shape
# Out:
# (984, 30)

# %%
count = new_cc['Class'].value_counts()
print("Total count in each class\n\n",count)

sb.countplot('Class', data=new_cc)
plt.title('Equally Distributed Classes', fontsize=14)
plt.show()
# Out:
# Total count in each class
#
#  1    492
# 0    492
# Name: Class, dtype: int64

# %%
X=new_cc.iloc[:,0:-1].values
y=new_cc.iloc[:,-1].values
from sklearn.preprocessing import StandardScaler
sim = StandardScaler()
X=sim.fit_transform(X)

# %%
sb.set(font_scale=1)
plt.figure(figsize=(20, 20))
corr=new_cc.corr()
sb.heatmap(corr,square=True, annot=True,cmap='YlGnBu',linecolor="black",annot_kws={'size':5})
plt.title('Correlation between features');

# %% [markdown]
# Negative Correlations: V17, V14, V12 and V10 are negatively correlated. Notice how the lower these values are, the more likely the end result will be a fraud transaction.
# Positive Correlations: V2, V4 and V11 are positively correlated. Notice how the higher these values are, the more likely the end result will be a fraud transaction.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((787, 29), (197, 29), (787,), (197,))

# %%
# !pip install xgboost-0.6-cp35-cp35m-win_amd32.whl
# Out:
# Requirement 'xgboost-0.6-cp35-cp35m-win_amd32.whl' looks like a filename, but the file does not exist
# xgboost-0.6-cp35-cp35m-win_amd32.whl is not a supported wheel on this platform.

# %%
import xgboost

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_curve, auc, precision_score,recall_score,f1_score

# %%
classifiers = [
    LogisticRegression(),
    KNeighborsClassifier(),
    SVC(),
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    XGBClassifier()
    ]

# %%
classifiers_columns = []
classifiers_compare = pd.DataFrame(columns = classifiers_columns)


row_index = 0
for alg in classifiers:
    
    
    alg.fit(X_train, y_train)
    y_pred= alg.predict(X_test)
    
    classifiers_name = alg.__class__.__name__
    classifiers_compare.loc[row_index,'Name'] = classifiers_name
    classifiers_compare.loc[row_index, 'Train Accuracy'] = round(alg.score(X_train, y_train), 4)
    classifiers_compare.loc[row_index, 'Test Accuracy'] = round(alg.score(X_test, y_test), 4)
    classifiers_compare.loc[row_index, 'accuracy_score'] = accuracy_score(y_test, alg.predict(X_test))
    classifiers_compare.loc[row_index, 'f1_score'] = f1_score(y_test, alg.predict(X_test))
    classifiers_compare.loc[row_index, 'recall_score'] = recall_score(y_test, alg.predict(X_test))
    classifiers_compare.loc[row_index, 'precision_score'] = precision_score(y_test, alg.predict(X_test))




    row_index+=1
    
classifiers_compare.sort_values(by = ['Test Accuracy'], ascending = False, inplace = True)    
classifiers_compare
# Out:
# C:\Users\pal\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\pal\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\pal\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
#                      Name  Train Accuracy  Test Accuracy  accuracy_score  \
# 0      LogisticRegression          0.9428         0.9543        0.954315
# 2                     SVC          0.9466         0.9442        0.944162
# ...

# %%
classifiers_compare.to_csv('C:/Users/pal/Desktop/dataset/comparison_table_CREDITCARD .csv', index=False)

# %%
import pickle

# %%
# XGBoost CV model
xgb = XGBClassifier(n_jobs=-1)
xgb.fit(X_train, y_train)
y_pred = xgb.predict(X_test)
y_score = xgb.predict_proba(X_test)[:,1]

# %%
pkl_filename = "XGB_model.pkl"
with open(pkl_filename, 'wb') as file:
    pickle.dump(classifiers_compare, file)

# %%
cm = confusion_matrix(y_test, y_pred)
sb.heatmap(cm, annot = True)

# %%
print(cm)
# Out:
# [[88  7]
#  [ 5 97]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94        95
#            1       0.93      0.95      0.94       102
#
#    micro avg       0.94      0.94      0.94       197
#    macro avg       0.94      0.94      0.94       197
# weighted avg       0.94      0.94      0.94       197
