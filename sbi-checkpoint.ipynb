# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
sbi=pd.read_csv("C:/Users/pal/Desktop/projects/project_5/SBI_Life_insurance.csv")

# %%
sbi.head(2)
# Out:
#    age  sex    bmi  children  smoker  region     charges  insuranceclaim
# 0   19    0  27.90         0       1       3  16884.9240               1
# 1   18    1  33.77         1       0       2   1725.5523               1

# %%
sbi.shape
# Out:
# (1338, 8)

# %%
sbi.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232    30.663397     1.094918     0.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     1.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             region       charges  insuranceclaim
# count  1338.000000   1338.000000     1338.000000
# mean      1.515695  13270.422265        0.585202
# std       1.104885  12110.011237        0.492871
# min       0.000000   1121.873900        0.000000
# 25%       1.000000   4740.287150        0.000000
# ...

# %%
sbi.isnull().sum()
# Out:
# age               0
# sex               0
# bmi               0
# children          0
# smoker            0
# region            0
# charges           0
# insuranceclaim    0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
variables = ['insuranceclaim', 'age','sex','smoker','region','bmi','children']

# data distribution analysys
print('Data distribution analysis')
for v in variables:
    d = sbi.sort_values(by=[v])
    d[v].value_counts().plot(kind = 'bar')
    plt.title(v)
    plt.show()
# Out:
# Data distribution analysis

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(x = "age", y = "charges", data = sbi, hue = "sex")
plt.xlabel("Age")
plt.ylabel("Charges")
plt.title("Distribution of charges by age and sex")
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.
# Text(0.5, 1.0, 'Distribution of charges by age and sex')

# %% [markdown]
# The charges definitely do increase with respect to age. There is no clear difference in charges for male vs female.

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(x = "age", y = "charges", data = sbi, hue = "smoker")
plt.xlabel("Age")
plt.ylabel("Charges")
plt.title("Distribution of charges by age and smoking")
# Out:
# Text(0.5, 1.0, 'Distribution of charges by age and smoking')

# %% [markdown]
# smoker with high age generally charge a much higher rate in comare to non smoker and younger age

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(x = "bmi", y = "charges", data = sbi, hue = "smoker")
plt.xlabel("bmi")
plt.ylabel("Charges")
plt.title("Distribution of charges by smoking and bmi")
# Out:
# Text(0.5, 1.0, 'Distribution of charges by smoking and bmi')

# %% [markdown]
# Smoker tends to incur a much higher charge as compared to non-smoker.Interestingly When the BMI of a smoker goes beyond 30, the charges increases to a minimum of 30000. Non-smoker with BMI > 30 generally have charges incurred below 30000.

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(x = "region", y = "charges", data = sbi, hue = "sex")
plt.xlabel("region")
plt.ylabel("Charges")
plt.title("Distribution of charges by region and sex")
# Out:
# Text(0.5, 1.0, 'Distribution of charges by region and sex')

# %%
plt.figure(figsize = (10,5))
sns.boxplot(x = "region", y = "charges", hue = "sex", data = sbi)

# %% [markdown]
# Across region 0, 1 and 3, the charges are rather similar. However, individuals from region 2 has a wider range of charges for both sexes.

# %%
plt.figure(figsize = (10,8))
sns.boxplot(x = "children", y = "charges", hue = "smoker", data = sbi)
plt.title("Distribution of charges by number of children")
# Out:
# Text(0.5, 1.0, 'Distribution of charges by number of children')

# %%
sns.heatmap(sbi.corr(), annot = True)

# %%
sns.pairplot(sbi, size=2)
# Out:
# C:\Users\pal\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
sbi.head(1)
# Out:
#    age  sex   bmi  children  smoker  region    charges  insuranceclaim
# 0   19    0  27.9         0       1       3  16884.924               1

# %%
from sklearn.metrics import r2_score, mean_squared_error
import statsmodels.api as sm
X = np.column_stack((sbi['age'], sbi['sex'], sbi['bmi'],sbi['children'], sbi['smoker'], sbi['region']))
y = sbi['charges']

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                charges   R-squared:                       0.751
# Model:                            OLS   Adj. R-squared:                  0.750
# Method:                 Least Squares   F-statistic:                     668.1
# Date:                Sun, 25 Aug 2019   Prob (F-statistic):               0.00
# Time:                        09:55:09   Log-Likelihood:                -13548.
# No. Observations:                1338   AIC:                         2.711e+04
# Df Residuals:                    1331   BIC:                         2.715e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.182e+04    955.130    -12.371      0.000   -1.37e+04   -9941.729
# ...

# %% [markdown]
# x2 and x6 coefficient i.e. sex and region has large p-value. So its not a good predictor for charges. will see if removing these two feature improve our prediction.

# %%
from sklearn.metrics import r2_score, mean_squared_error
import statsmodels.api as sm
X = np.column_stack((sbi['age'], sbi['bmi'],sbi['children'], sbi['smoker']))
y = sbi['charges']

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                charges   R-squared:                       0.750
# Model:                            OLS   Adj. R-squared:                  0.749
# Method:                 Least Squares   F-statistic:                     998.1
# Date:                Sun, 25 Aug 2019   Prob (F-statistic):               0.00
# Time:                        09:55:09   Log-Likelihood:                -13551.
# No. Observations:                1338   AIC:                         2.711e+04
# Df Residuals:                    1333   BIC:                         2.714e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -1.21e+04    941.984    -12.848      0.000    -1.4e+04   -1.03e+04
# ...

# %% [raw]
# removing these two feature doesn't improve r2 which remain same but good news is that value of f-state increase 668 to 998.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
lig=LinearRegression()
X = sbi.drop(["charges","region","sex", "insuranceclaim"], axis = 1)
y = sbi["charges"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1003, 4)
# (335, 4)
# (1003,)
# (335,)

# %%
lig.fit(X_train,y_train)
y_pred= lig.predict(X_test)
lig.score(X_test,y_test)
# Out:
# 0.7249935168295808

# %%
print(np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# 6022.306016453881

# %%
import xgboost
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_curve, auc, precision_score,recall_score,f1_score

# %%
sbi.head(1)
# Out:
#    age  sex   bmi  children  smoker  region    charges  insuranceclaim
# 0   19    0  27.9         0       1       3  16884.924               1

# %%
X = sbi.drop(["insuranceclaim"], axis = 1)
y = sbi["insuranceclaim"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1003, 7)
# (335, 7)
# (1003,)
# (335,)

# %%
classifiers = [
    LogisticRegression(),
    KNeighborsClassifier(),
    SVC(),
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    XGBClassifier()
    ]

# %%
classifiers_columns = []
classifiers_compare = pd.DataFrame(columns = classifiers_columns)


row_index = 0
for alg in classifiers:
    
    
    alg.fit(X_train, y_train)
    y_pred= alg.predict(X_test)
    
    classifiers_name = alg.__class__.__name__
    classifiers_compare.loc[row_index,'Name'] = classifiers_name
    classifiers_compare.loc[row_index, 'Train Accuracy'] = round(alg.score(X_train, y_train), 4)
    classifiers_compare.loc[row_index, 'Test Accuracy'] = round(alg.score(X_test, y_test), 4)
    classifiers_compare.loc[row_index, 'accuracy_score'] = accuracy_score(y_test, alg.predict(X_test))
    classifiers_compare.loc[row_index, 'f1_score'] = f1_score(y_test, alg.predict(X_test))
    classifiers_compare.loc[row_index, 'recall_score'] = recall_score(y_test, alg.predict(X_test))
    classifiers_compare.loc[row_index, 'precision_score'] = precision_score(y_test, alg.predict(X_test))




    row_index+=1
    
classifiers_compare.sort_values(by = ['Test Accuracy'], ascending = False, inplace = True)    
classifiers_compare
# Out:
# C:\Users\pal\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\pal\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\pal\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
#                      Name  Train Accuracy  Test Accuracy  accuracy_score  \
# 3  DecisionTreeClassifier          1.0000         0.9761        0.976119
# 5           XGBClassifier          0.9840         0.9582        0.958209
# ...

# %%
classifiers_compare.to_csv('C:/Users/pal/Desktop/dataset/comparison_table_sbi .csv', index=False)

# %%
import pickle
pkl_filename = "sbi_model.pkl"
with open(pkl_filename, 'wb') as file:
    pickle.dump(classifiers_compare, file)
